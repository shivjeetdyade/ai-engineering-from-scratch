# %%
import numpy as np

# %timeit [i for i in range(100000)]
# %timeit np.arange(100000)
# Out:
# 3.17 ms ± 488 μs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 34.6 μs ± 1.96 μs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# # Markdown cell (press M after Escape to convert)
# ## My first data exploration

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.DataFrame({
    "model": ["Linear", "Random Forest", "Neural Net"],
    "accuracy": [0.72, 0.89, 0.94]
})
df

# %%
# %matplotlib inline
plt.bar(df["model"], df["accuracy"])
plt.title("Model Comparison")
plt.show()
